# %%
import requests

response = requests.get('http://www.baidu.com/')
print(type(response))
print(response.status_code)
print(type(response.text))
print(response.cookies)
# Out:
# <class 'requests.models.Response'>
# 200
# <class 'str'>
# <RequestsCookieJar[<Cookie BDORZ=27315 for .baidu.com/>]>

# %%
import requests
import json

data = {
    'name':'Dragon',
    'age':22
}

response = requests.get('http://httpbin.org/get',params = data)
print(response.text)
print('---------------------------------------------------------------------------------------------------------------------')
print(response.json())
print('---------------------------------------------------------------------------------------------------------------------')
print(json.loads(response.text))
print('---------------------------------------------------------------------------------------------------------------------')
print(type(response.json()))
# Out:
# {
#   "args": {
#     "age": "22",
#     "name": "Dragon"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.21.0"
#   },
#   "origin": "211.140.166.187, 211.140.166.187",
#   "url": "https://httpbin.org/get?name=Dragon&age=22"
# }
#
# ---------------------------------------------------------------------------------------------------------------------
# {'args': {'age': '22', 'name': 'Dragon'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.21.0'}, 'origin': '211.140.166.187, 211.140.166.187', 'url': 'https://httpbin.org/get?name=Dragon&age=22'}
# ---------------------------------------------------------------------------------------------------------------------
# ...

# %%
import requests

response = requests.get('https://i0.hdslb.com/bfs/sycp/creative_img/201904/d8c49d0dbb8c4182916b590c81228bc9.jpg@880w_440h.jpg')
with open('d8c49d0dbb8c4182916b590c81228bc9.jpg','wb') as f:
    f.write(response.content)
    f.close()
#    f.close()可不用调用

# %%
import requests
data = {
    'name':'Dragon',
    'age':22
}
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.131 Safari/537.36'
}
response = requests.get('http://www.zhihu.com/explore',headers=headers)
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN" dropEffect="none" class="no-js no-auth ">
# <head>
# <meta charset="utf-8" />
#
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
# <meta name="renderer" content="webkit" />
# <meta http-equiv="X-ZA-Response-Id" content="94d0f0efc219954377945b1c6e384f7d">
#
# <meta http-equiv="X-ZA-Experiment" content="default:None,ge3:ge3_9,ge2:ge2_1,nwebQAGrowth:experiment,is_office:false,nweb_growth_people:default,app_store_rate_dialog:close,live_store:ls_a2_b2_c1_f2,nweb_search:nweb_search_heifetz,new_live_feed_mediacard:new,hybrid_zhmore_video:yes,ad_r:a,growth_search:s2,qaweb_related_readings_content_control:close,search_hybrid_tabs:pin-3#album-7,android_pass_through_push:all,nweb_search_suggest:default,android_search_tab_style:search_tab_style_b,android_db_recommend_action:open,android_db_feed_hash_tag_style:button,is_new_noti_panel:no">
# <title>发现 - 知乎</title>
#
# ...

# %%
import requests
data = {
    'name':'Dragon',
    'age':22
}
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.131 Safari/537.36'
}
response = requests.post('http://httpbin.org/post',data = data , headers=headers)
print(response.json())
# Out:
# {'args': {}, 'data': '', 'files': {}, 'form': {'age': '22', 'name': 'Dragon'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Content-Length': '18', 'Content-Type': 'application/x-www-form-urlencoded', 'Host': 'httpbin.org', 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.131 Safari/537.36'}, 'json': None, 'origin': '211.140.166.155, 211.140.166.155', 'url': 'https://httpbin.org/post'}

# %% [markdown]
# # 获取Cookie

# %%
import requests

response = requests.get('https://www.baidu.com')
print(response.cookies)
for key,value in response.cookies.items():
    print(key + "=" + value)
# Out:
# <RequestsCookieJar[<Cookie BDORZ=27315 for .baidu.com/>]>
# BDORZ=27315

# %% [markdown]
# # 证书验证

# %%
import requests

response = requests.get('https://www.12306.cn')
print(response.status_code)
# Out:
# 200

# %% [markdown]
# # 代理

# %%
import requests

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.131 Safari/537.36'}
proxies = {
    "http":"http://60.190.250.120:8080",
    "https":"https://60.190.250.120:8080",
}

response = requests.get("https://www.taobao.com",proxies = proxies)
print(response.status_code)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# c:\python37\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# c:\python37\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# c:\python37\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# ...
